# %%
from langchain.text_splitter import CharacterTextSplitter
splitter = CharacterTextSplitter(chunk_size=10, chunk_overlap=2)
print("Langchain charactertextsplitter works")
# Out:
# Langchain charactertextsplitter works

# %%
# load sample doc
with open("sample.txt", "r", encoding="utf-8")as f:
    text = f.read()

#splitt text
splitter = CharacterTextSplitter(chunk_size=10, chunk_overlap=2)
chunks = splitter.split_text(text)

#inspect chunks
print(f"Total chunks created: {len(chunks)}")
print(chunks[:3]) # first 3 chunks
# Out:
# Total chunks created: 1
# ['finally i have completed the importing files it took me so much time still i am happy i learned so many things while dealing with the errors and focusing on my 1st project agentic rag optimizer and i wish i could complete the project without any more conflicts it is asking me to write some more words that it can work perfectly now it is showin chunk 1 created because i have created the smaller text and i give  chunk size 100 so ihave to create more thank 100 so then it will create more if i will increase the text size thats what i am doing right now i wish it have 100 chunks.\nit has several sentences to test the test splitter functionality.\nhere is a second paragraph to ensure we get multiple chunks\nfinally the third paragraph will help check overlaping behaviour']

# %%
with open("sample.txt", "r", encoding="utf-8")as f:
    text = f.read()
    
print("lenght of text:", len(text))
print("first 20 characters:\n", text[:50])
# Out:
# lenght of text: 773
# first 20 characters:
#  finally i have completed the importing files it to

# %%
from langchain.text_splitter import CharacterTextSplitter
splitter = CharacterTextSplitter(chunk_size=20,
                                 chunk_overlap=2,
                                 separator="")
chunks = splitter.split_text(text)
print(f"total chunks created: {len(chunks)}")
print("first 5 chunks:")
for i, c in enumerate(chunks[:5]):
    print(f"chunks{i+1}: '{c}'")
# Out:
# total chunks created: 43
# first 5 chunks:
# chunks1: 'finally i have compl'
# chunks2: 'pleted the importing'
# chunks3: 'ng files it took me'
# chunks4: 'e so much time still'
# chunks5: 'll i am happy i lear'
