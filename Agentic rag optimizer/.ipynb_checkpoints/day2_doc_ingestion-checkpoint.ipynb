# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install pandas PyPDF2 python-docx langchain
# Out:
# Requirement already satisfied: pip in c:\users\radha\rag_env\lib\site-packages (22.2.2)
# Collecting pip
#   Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# Successfully installed pip-26.0.1
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: PyPDF2 in .\rag_env\lib\site-packages (3.0.1)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: langchain in .\rag_env\lib\site-packages (0.0.239)
# Requirement already satisfied: numpy>=1.22.4 in .\rag_env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\rag_env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in .\rag_env\lib\site-packages (from pandas) (2025.3)
# Collecting lxml>=3.1.0 (from python-docx)
#   Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in .\rag_env\lib\site-packages (from python-docx) (4.15.0)
# Requirement already satisfied: PyYAML>=5.4.1 in .\rag_env\lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in .\rag_env\lib\site-packages (from langchain) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\rag_env\lib\site-packages (from langchain) (3.13.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in .\rag_env\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in .\rag_env\lib\site-packages (from langchain) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.11 in .\rag_env\lib\site-packages (from langchain) (0.0.92)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in .\rag_env\lib\site-packages (from langchain) (2.14.1)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in .\rag_env\lib\site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in .\rag_env\lib\site-packages (from langchain) (1.10.26)
# Requirement already satisfied: requests<3,>=2 in .\rag_env\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\rag_env\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\rag_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\rag_env\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\rag_env\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in .\rag_env\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (26.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\rag_env\lib\site-packages (from requests<3,>=2->langchain) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in .\rag_env\lib\site-packages (from requests<3,>=2->langchain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\rag_env\lib\site-packages (from requests<3,>=2->langchain) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\rag_env\lib\site-packages (from requests<3,>=2->langchain) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in .\rag_env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\rag_env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.1.0)
# Requirement already satisfied: six>=1.5 in .\rag_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 1.3 MB/s eta 0:00:09
#    --- ------------------------------------ 1.0/11.3 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/11.3 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.3 MB 1.7 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.3 MB 1.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.3 MB 1.9 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/11.3 MB 2.0 MB/s eta 0:00:05
#    -------------- ------------------------- 4.2/11.3 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.0/11.3 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.3 MB 2.6 MB/s eta 0:00:03
#    ------------------------ --------------- 6.8/11.3 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 2.9 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.3 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.3 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 3.3 MB/s  0:00:03
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/4.0 MB 6.1 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 6.0 MB/s  0:00:00
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz, lxml, python-docx, pandas
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [lxml]
#    ---------- ----------------------------- 1/4 [lxml]
#    -------------------- ------------------- 2/4 [python-docx]
#    -------------------- ------------------- 2/4 [python-docx]
#    -------------------- ------------------- 2/4 [python-docx]
#    -------------------- ------------------- 2/4 [python-docx]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ---------------------------------------- 4/4 [pandas]
#
# Successfully installed lxml-6.0.2 pandas-2.3.3 python-docx-1.2.0 pytz-2026.1.post1

# %%
pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in .\rag_env\lib\site-packages (3.0.1)Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\RADHA\rag_env\Scripts\python.exe

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\radha\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\radha\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\radha\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\radha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\radha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\radha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#step 1 importing all libraries
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
import pandas as pd 
from PyPDF2 import PdfReader
from docx import Document
print("all libraries are ready")
# Out:
# all libraries are ready

# %%
import os
if not os.path.exists("data"):
    os.makedirs("data")
    print("created 'data/' folder.")
else:
    print("'data/' folder already exists.")
# Out:
# created 'data/' folder.

# %%
# step 2 :--functions to read different document types
def read_txt(file_path):
    with open(file_path, 'r', encoding='utf-8')as f:
        return f.read()

def read_pdf(file_path):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() + "\n"
    return text

def read_docx(file_path):
    doc = Document(file_path)
    return "\n".join([para.text for para in doc.paragraphs])

# %%
# step 3:--initialize text splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=50,#charactes per chunk
                                               chunk_overlap=5)#overlap between chunks

# %%
# step4:-- Load all documents from data folder to split into chunks
all_chunks = []

for file in os.listdir("data"):
    file_path = os.path.join("data", file)

    if file.endswith(".txt"):
        text = read_txt(file_path)
    elif file.endswith(".pdf"):
        text = read_pdf(file_path)
    elif file.endswith(".docx"):
        text = read_docx(file_path)
    else:
        continue
    chunks = text_splitter.split_text(text)
    for i,chunk in enumerate(chunks):
        all_chunks.append({"source": file,
                           "chunk_id": i,
                           "text": chunk })

# step 5:-- create dataframe and inspect
df_chunks = pd.DataFrame(all_chunks)
print("first 5 chunks")
print(df_chunks.head())

# step 6:-- save the chunks to csv for day 3
df_chunks.to_csv("data/chunks_day2.csv", index=False)
print("chunks saved to 'data/chunks_day2.csv'")
# Out:
# first 5 chunks
# Empty DataFrame
# Columns: []
# Index: []
# chunks saved to 'data/chunks_day2.csv'
